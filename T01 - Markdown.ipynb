# %% [markdown]
# Lunes 14 de Agosto del 2023

# %% [markdown]
# # Tarea 1 - Markdown

# %% [markdown]
# ## Presentación Personal

# %% [markdown]
# Mi nombre es **Matias Medrano Ascencio**, y soy alumno de tercer semestre de *Ingeniería Civil* en el ITESO. Tengo 19 años y soy originario de Guadalajara. Me gusta mucho dibujar, el cine y aprender acerca de otras culturas e idiomas. Elegí mi carrera ya que me interesa el sector de la construcción y todos los factores que juegan un papel, principalmente el cálculo estructural.

# %% [markdown]
# ## Losa aligerada

# %% [markdown]
# La **losa aligerada** es un sistema constructivo liviano, en donde el concreto es remplazado con otros materiales (usualmente *poliestireno*). Resulta una manera más práctica y económica de cubrir espacios con volúmenes mínimos de concreto y cuenta con un proceso de elaboración sencillo.

# %% [markdown]
# Está conformada por:
# - Caseton de poliestireno
# - Vigueta
# - Malla de acero electro soldada
# - Capa de concreto

# %% [markdown]
# Desde el punto de vista estructural, las losas aligeradas cumplen tres funciones específicas:
# 1. Transmiten hacia los muros o vigas el peso de los acabados, su mismo peso, el peso de los objetos, el de las personas, etc.
# 2. Dirigen hacia los muros las fuerzas que producen los terremotos.
# 3. Unen los otros elementos estructurales (columnas, vigas y muros) para que toda la estructura funcione en conjunto.

# %% [markdown]
# ![acomodo%20de%20caseton-2.jpg](attachment:acomodo%20de%20caseton-2.jpg)

# %% [markdown]
# Se recomienda utilizar un concreto con resistencia de:

# %% [markdown]
# $ f'c=250 kg/cm^3 $
